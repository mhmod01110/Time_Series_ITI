# %%
import seaborn as sns
import numpy as np
import time
from sklearn.metrics import r2_score
import math
from sklearn import svm,preprocessing
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from numpy import array
import numpy as np
import numpy
# %timeit
from sklearn.datasets import load_linnerud
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

import xgboost as xg
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
import random
from tensorflow.compat.v1.random import set_random_seed

random.seed(1)
numpy.random.seed(1)
set_random_seed(2)

# %%
df = pd.read_csv ("USDJPY 1.csv")
df.head()
# Out:
#      Results USD/JPY Close USD/JPY High USD/JPY Low
# 0    Average       106.590      107.053     106.102
# 1    Minimum        75.720       76.000      75.550
# 2    Maximum       134.780      135.150     134.100
# 3        Std        13.217       13.244      13.182
# 4  # In Calc          5217         5217        5217

# %%
df=df.loc[::-1]
df.head()
# Out:
#          Results USD/JPY Close USD/JPY High USD/JPY Low
# 5222  2019-12-31        108.62       108.89      108.48
# 5221  2019-12-30        108.83        109.5      108.76
# 5220  2019-12-27        109.45       109.64      109.44
# 5219  2019-12-26        109.62       109.69      109.32
# 5218  2019-12-25        109.55       109.58      109.32

# %%
df.rename(columns = {'USD/JPY Close':'close','USD/JPY High':'high','USD/JPY Low':'low', 'Results': 'results'}, inplace = True)
df.head()
# Out:
#          results   close    high     low
# 5222  2019-12-31  108.62  108.89  108.48
# 5221  2019-12-30  108.83   109.5  108.76
# 5220  2019-12-27  109.45  109.64  109.44
# 5219  2019-12-26  109.62  109.69  109.32
# 5218  2019-12-25  109.55  109.58  109.32

# %%
df.dtypes
# Out:
# results    object
# close      object
# high       object
# low        object
# dtype: object

# %%
df["close-shifted"] = df.close.shift(1)
df["high-shifted"] = df.high.shift(1)
df["low-shifted"] = df.low.shift(1)

df.head()
# Out:
#          results   close    high     low close-shifted high-shifted  \
# 5222  2019-12-31  108.62  108.89  108.48          None         None
# 5221  2019-12-30  108.83   109.5  108.76        108.62       108.89
# 5220  2019-12-27  109.45  109.64  109.44        108.83        109.5
# 5219  2019-12-26  109.62  109.69  109.32        109.45       109.64
# 5218  2019-12-25  109.55  109.58  109.32        109.62       109.69
#
#      low-shifted
# 5222        None
# 5221      108.48
# 5220      108.76
# 5219      109.44
# 5218      109.32

# %%
df=df.dropna()
df.isna().sum()
# Out:
# results          0
# close            0
# high             0
# low              0
# close-shifted    0
# high-shifted     0
# low-shifted      0
# dtype: int64

# %%
df.head(2)
# Out:
#          results   close    high     low close-shifted high-shifted  \
# 5221  2019-12-30  108.83   109.5  108.76        108.62       108.89
# 5220  2019-12-27  109.45  109.64  109.44        108.83        109.5
#
#      low-shifted
# 5221      108.48
# 5220      108.76

# %%
columns_to_convert = ['close', 'high', 'low', 'close-shifted', 'high-shifted', 'low-shifted']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df.isna().sum()
# Out:
# results          0
# close            1
# high             1
# low              1
# close-shifted    1
# high-shifted     1
# low-shifted      1
# dtype: int64

# %%
df.head(2)
# Out:
#          results   close    high     low  close-shifted  high-shifted  \
# 5221  2019-12-30  108.83  109.50  108.76         108.62        108.89
# 5220  2019-12-27  109.45  109.64  109.44         108.83        109.50
#
#       low-shifted
# 5221       108.48
# 5220       108.76

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# results          0
# close            0
# high             0
# low              0
# close-shifted    0
# high-shifted     0
# low-shifted      0
# dtype: int64

# %%
df.dtypes
# Out:
# results           object
# close            float64
# high             float64
# low              float64
# close-shifted    float64
# high-shifted     float64
# low-shifted      float64
# dtype: object

# %%
df=df[['high-shifted','low-shifted','close-shifted','close']]
df_without_scale=df

# %%
df.head(7)
# Out:
#       high-shifted  low-shifted  close-shifted   close
# 5221        108.89       108.48         108.62  108.83
# 5220        109.50       108.76         108.83  109.45
# 5219        109.64       109.44         109.45  109.62
# 5218        109.69       109.32         109.62  109.55
# 5217        109.58       109.32         109.55  109.37
# 5216        109.44       109.33         109.37  109.35
# 5215        109.54       109.34         109.35  109.44

# %%
df.columns
# Out:
# Index(['high-shifted', 'low-shifted', 'close-shifted', 'close'], dtype='object')

# %%
close_3thdDayClose=df[["close-shifted",'close']]
close_3thdDayClose.head(10)
# Out:
#       close-shifted   close
# 5221         108.62  108.83
# 5220         108.83  109.45
# 5219         109.45  109.62
# 5218         109.62  109.55
# 5217         109.55  109.37
# 5216         109.37  109.35
# 5215         109.35  109.44
# 5214         109.44  109.24
# 5213         109.24  109.57
# 5212         109.57  109.48

# %%
data=df.to_numpy()
df.head(3)
# Out:
#       high-shifted  low-shifted  close-shifted   close
# 5221        108.89       108.48         108.62  108.83
# 5220        109.50       108.76         108.83  109.45
# 5219        109.64       109.44         109.45  109.62

# %%
df.shape
# Out:
# (5220, 4)

# %%
x_close=df

# %%
percentage = 90
split=x_close.shape[0]*percentage//100
split
# Out:
# 4698

# %%
df_train=x_close.iloc[:split,:]
df_train.shape
# Out:
# (4698, 4)

# %%
df_test=x_close.iloc[split:,:]
df_test.shape
# Out:
# (522, 4)

# %%
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
dataset_train=df_train.values
dataset_test=df_test.values

# %%
n_steps_in, n_steps_out = 7,3
# convert into input/output
train_x, train_y = split_sequences(dataset_train, n_steps_in, n_steps_out)

# %%
df_train.head(17)
# Out:
#       high-shifted  low-shifted  close-shifted   close
# 5221        108.89       108.48         108.62  108.83
# 5220        109.50       108.76         108.83  109.45
# 5219        109.64       109.44         109.45  109.62
# 5218        109.69       109.32         109.62  109.55
# 5217        109.58       109.32         109.55  109.37
# 5216        109.44       109.33         109.37  109.35
# 5215        109.54       109.34         109.35  109.44
# 5214        109.53       109.26         109.44  109.24
# 5213        109.69       109.19         109.24  109.57
# 5212        109.63       109.40         109.57  109.48
# 5211        109.64       109.45         109.48  109.62
# 5210        109.68       109.31         109.62  109.29
# 5209        109.71       109.21         109.29  109.33
# 5208        109.45       108.46         109.33  108.54
# 5207        108.85       108.48         108.54  108.72
# 5206        108.77       108.52         108.72  108.63
# 5205        108.68       108.43         108.63  108.56

# %%
train_x.shape
# Out:
# (4690, 7, 3)

# %%
train_x[:1]
# Out:
# array([[[108.89, 108.48, 108.62],
#         [109.5 , 108.76, 108.83],
#         [109.64, 109.44, 109.45],
#         [109.69, 109.32, 109.62],
#         [109.58, 109.32, 109.55],
#         [109.44, 109.33, 109.37],
#         [109.54, 109.34, 109.35]]])

# %%
train_y
# Out:
# array([[109.44, 109.24, 109.57],
#        [109.24, 109.57, 109.48],
#        [109.57, 109.48, 109.62],
#        ...,
#        [132.11, 131.56, 131.56],
#        [131.56, 131.56, 131.11],
#        [131.56, 131.11, 131.71]])

# %%
# convert into input/output
test_x, test_y = split_sequences(dataset_test, n_steps_in, n_steps_out)

# %%
train_x=train_x.reshape(train_x.shape[0],train_x.shape[1]*train_x.shape[2])
train_x.shape
# Out:
# (4690, 21)

# %%
train_y=train_y.reshape(train_y.shape[0],train_y.shape[1])
train_y.shape
# Out:
# (4690, 3)

# %%
test_x=test_x.reshape(test_x.shape[0],test_x.shape[1]*test_x.shape[2])
test_x.shape
# Out:
# (514, 21)

# %%
test_y=test_y.reshape(test_y.shape[0],test_y.shape[1])
test_y.shape
# Out:
# (514, 3)

# %% [markdown]
# # SVR

# %% [markdown]
# ##  Results

# %%
regr = MultiOutputRegressor(SVR(kernel='linear',C=1e1,epsilon=0.0001,verbose=False,cache_size=15000)).fit(train_x, train_y)
y_predict4=regr.predict(test_x)
#%%timeit
print('------------------------------------------------------------------')
result4=mean_absolute_error(test_y, y_predict4)
result4=round(result4, 6)
result4='{:f}'.format(result4)
print('MAE linear',result4)
result5=mean_squared_error(test_y, y_predict4)
result5=round(result5, 6)
result5='{:f}'.format(result5)
print('MSE linear',result5)
RE=round(r2_score(test_y, y_predict4),6)
result1='{:f}'.format(RE)
print('r2',result1)
# Out:
# ------------------------------------------------------------------
# MAE linear 14.269687
# MSE linear 76169.280672
# r2 -1043.174277

# %%
regr = MultiOutputRegressor(SVR(kernel='rbf',C=1e1,epsilon=0.0001,verbose=False,cache_size=15000)).fit(train_x, train_y)
y_predict4=regr.predict(test_x)
#%%timeit
print('------------------------------------------------------------------')
result4=mean_absolute_error(test_y, y_predict4)
result4=round(result4, 6)
result4='{:f}'.format(result4)
print('MAE rbf',result4)
result5=mean_squared_error(test_y, y_predict4)
result5=round(result5, 6)
result5='{:f}'.format(result5)
print('MSE rbf',result5)
RE=round(r2_score(test_y, y_predict4),6)
result1='{:f}'.format(RE)
print('r2',result1)
# Out:
# ------------------------------------------------------------------
# MAE rbf 0.845541
# MSE rbf 19.538916
# r2 0.735224

# %%
regr = MultiOutputRegressor(SVR(kernel='poly',C=1e1,epsilon=0.001,degree=3,verbose=False,cache_size=15000)).fit(train_x, train_y)
y_predict4=regr.predict(test_x)
#%%timeit
print('----------------------------poly 3--------------------------------------')
result4=mean_absolute_error(test_y, y_predict4)
result4=round(result4, 6)
result4='{:f}'.format(result4)
print('MAE Poly 3',result4)
result5=mean_squared_error(test_y, y_predict4)
result5=round(result5, 6)
result5='{:f}'.format(result5)
print('MSE Poly 3',result5)
RE=round(r2_score(test_y, y_predict4),6)
result1='{:f}'.format(RE)
print('r2',result1)
# Out:
# ----------------------------poly 3--------------------------------------
# MAE Poly 3 17429.419246
# MSE Poly 3 123483646201.220093
# r2 -1666594960.970125

# %%
regr = MultiOutputRegressor(SVR(kernel='poly',C=1e1,epsilon=0.0001,degree=2,verbose=False,cache_size=15000)).fit(train_x, train_y)
y_predict4=regr.predict(test_x)
#%%timeit
print('----------------------------poly 2--------------------------------------')
result4=mean_absolute_error(test_y, y_predict4)
result4=round(result4, 6)
result4='{:f}'.format(result4)
print('MAE Poly 2',result4)
result5=mean_squared_error(test_y, y_predict4)
result5=round(result5, 6)
result5='{:f}'.format(result5)
print('MSE Poly 2',result5)
RE=round(r2_score(test_y, y_predict4),6)
result1='{:f}'.format(RE)
print('r2',result1)
# Out:
# ----------------------------poly 2--------------------------------------
# MAE Poly 2 80.596065
# MSE Poly 2 3087456.883161
# r2 -41810.438409

# %% [markdown]
# # XGBoost

# %%
train_y=train_y.reshape((train_y.shape[0],n_steps_out))
train_y.shape
# Out:
# (4690, 3)

# %%
# Instantiation
xgb_r = xg.XGBRegressor( n_estimators =60,max_depth=80)

# Fitting the model
xgb_r.fit(train_x, train_y)

# Predict the model
pred = xgb_r.predict(test_x)
print('MAE xGBOOST',round(mean_absolute_error(test_y, pred),6))
print('MSE xGBOOST',round(mean_squared_error(test_y, pred),6))

print('R2 xGBOOST',round(r2_score( test_y,pred),6))
# Out:
# MAE xGBOOST 0.994291
# MSE xGBOOST 25.061767
# R2 xGBOOST 0.658803
